# %% [markdown]
# <a href="https://colab.research.google.com/github/fabrytp8/deepLearning/blob/main/Proyecto_Final_Fabricio_Tipantocta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **07MIAR_Proyecto_Programacion_Fabricio_Tipantocta**
#
# Julio, 2022

# %% [markdown]
# ## **1. 07MIAR - Redes Neuronales y Deep Learning: Proyecto de programación ”Deep Vision in classification tasks”**

# %% [markdown]
# ##**1.1 Enunciado**
#
# En esta actividad, el alumno debe **evaluar y comparar dos estrategias** para la **clasificación de imágenes** empleando el **dataset asignado**. El/La alumnx deberá resolver el reto proponiendo una solución válida **basada en aprendizaje profundo**, más concretamente en redes neuronales convolucionales (**CNNs**). Será indispensable que la solución propuesta siga el **pipeline visto en clase** para resolver este tipo de tareas de inteligencia artificial:
#
# 1.   **Carga** del conjunto de datos
# 2.   **Inspección** del conjunto de datos
# 3.   **Acondicionamiento** del conjunto de datos
# 4.   Desarrollo de la **arquitectura** de red neuronal y **entrenamiento** de la solución
# 5.   **Monitorización** del proceso de **entrenamiento** para la toma de decisiones
# 6.   **Evaluación** del modelo predictivo y planteamiento de la siguiente prueba experimental
#
# ### Estrategia 1: Entrenar desde cero o *from scratch*
#
# La primera estrategia a comparar será una **red neuronal profunda** que el **alumno debe diseñar, entrenar y optimizar**. Se debe **justificar empíricamente** las decisiones que llevaron a la selección de la **arquitectura e hiperparámetros final**. Se espera que el alumno utilice todas las **técnicas de regularización** mostradas en clase de forma justificada para la mejora del rendimiento de la red neuronal (*weight regularization*, *dropout*, *batch normalization*, *data augmentation*, etc.).
#
# ### Estrategia 2: Red pre-entrenada
#
# La segunda estrategia a comparar debe incluir la utilización de una **red preentrenada** con el dataset ImageNet, llevando a cabo tareas de ***transfer learning*** y ***fine-tuning*** para resolver la tarea de clasificación asignada. Deben **compararse al menos dos tipos de arquitecturas** (VGGs, ResNet50, Xception, InceptionV3, InceptionResNetV2, MobileNetV2, DenseNet, ResNet) y se debe **seleccionar la que mayor precisión proporcione** (información sobre las arquitecturas disponibles en https://keras.io/applications/). Se espera que el/la alumnx utilice todas las **técnicas de regularización** mostradas en clase de forma justificada para la mejora del rendimiento de la red neuronal (*weight regularization*, *dropout*, *batch normalization*, *data augmentation*, etc.).

# %% [markdown]
# ## **1.2 Normas a seguir**
#
# - Será **indispensable** realizar el **trabajo por parejas**. Dichas parejas de alumnxs se generarán **de manera automática** teniendo en cuenta el pais de residencia con el objetivo de facilitar el trabajo en equipo.
# - Se debe entregar un **ÚNICO FICHERO PDF POR ALUMNO** que incluya las instrucciones presentes en el Colab Noteboook y su **EJECUCIÓN!!!**. Debe aparecer todo el proceso llevado a cabo en cada estrategia (i.e. carga de datos, inspección de datos, acondicionamiento, proceso de entrenamiento y proceso de validación del modelo).
# - **La memoria del trabajo** (el fichero PDF mencionado en el punto anterior) deberá **subirla cada integrante del grupo** (aunque se trate de un documento idéntico) a la actividad que se habilitará **en CampusVIU**.
# - Se recomienda trabajar respecto a un directorio base (**BASE_FOLDER**) para facilitar el trabajo en equipo. En este notebook se incluye un ejemplo de cómo almacenar/cargar datos utilizando un directorio base.
# - Las **redes propuestas** deben estar **entrenadas** (y **EVIDENCIAR este proceso en el documento PDF**). La entrega de una **red sin entrenar** supondrá **perdida de puntos**.
# - Si se desea **evidenciar alguna métrica** del proceso de entrenamiento (precisión, pérdida, etc.), estas deben ser generadas.
# - Todos los **gráficos** que se deseen mostrar deberán **generarse en el Colab Notebook** para que tras la conversión aparezcan en el documento PDF.

# %% [markdown]
# ## **1.3 Tips para realizar la actividad con éxito**
# - Los **datos** se cargarán directamente **desde** la plataforma **Kaggle** mediante su API (https://github.com/Kaggle/kaggle-api). En este Notebook se incluye un ejemplo de como hacerlo. Se recomienda generar una función que aborde esta tarea.
# - El **documento PDF a entregar** como solución de la actividad se debe **generar automáticamente desde el fichero ".ipynb"**. En este Notebook se incluye un ejemplo de como hacerlo.
# - **Generar secciones y subsecciones en el Colab Notebook** supondrá que el documento **PDF generado** queda totalmente **ordenado** facilitando la evaluación al docente.
# - Se recomienda encarecidamente **incluir comentarios concisos pero aclaratorios**.
# - Es muy recomendable crear una **última sección** de texto en el Colab Notebook en la que se discutan los diferentes modelos obtenidos y se extraigan las conclusiones pertinentes.
#
# ## **1.4 Criterios de evaluación**
#
# - **Seguimiento** de las **normas establecidas** en la actividad (detalladas anteriormente).
# - Creación de una **solución que resuelva la tarea de clasificación**, i.e. que las figuras de mérito empleadas para medir la bondad del modelo predictivo evidencien un *performance* superior al rendimiento estocástico.
# - **Claridad** en la creación de la solución, en las justificaciones sobre la toma de decisiones llevada a cabo así como en las comparativas y conclusiones finales.
# - **Efectividad** al presentar las comparaciones entre métricas de evaluación de ambas estrategias.
# - **Demostración** de la utilización de **técnicas de regularización** para mejorar el rendimiento de los modelos.

# %% [markdown]
# ## **2. Carga de datos desde la plataforma Kaggle**

# %%
# En primer lugar se debe generar un API de Kaggle personal, para ello:
#  1. Registrarse en https://www.kaggle.com
#  2. Ir a 'Account tab' de tu perfil y seleccionar 'Create API Token'
#  3. Almacenar en tu ordenador local el fichero kaggle.json

# %%
# Nos aseguramos que tenemos instalada la última versión de la API de Kaggle en Colab
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 58 kB 2.1 MB/s
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73051 sha256=22c61360313108fb9e0d7452395bb0b68233c480791323ae84c3b065f9766486
#   Stored in directory: /root/.cache/pip/wheels/62/d6/58/5853130f941e75b2177d281eb7e44b4a98ed46dd155f556dc5
# Successfully built kaggle
# ...
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.12
#     Uninstalling kaggle-1.5.12:
#       Successfully uninstalled kaggle-1.5.12
# ...

# %%
# Seleccionar el API Token personal previamente descargado (fichero kaggle.json)
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-193f3e98-2f2a-4c8d-872a-53a8009353b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-193f3e98-2f2a-4c8d-872a-53a8009353b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"fabrytp","key":"938e4aa535c98a32f9af99e35727b3cf"}'}

# %%
# Creamos un directorio en el que copiamos el fichero kaggle.json
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Ya podemos listar los datasets disponibles en kaggle para su descarga
# %%capture
# !kaggle datasets list

# %% [markdown]
# # **3. Conjunto de datos**
#
# **Conjunto de datos:** Dog Breed Identification
#
# **Objetivo:** Determinar el tipo de raza de perro dado el dataset.
#
# **Descripción de datos:** El dataset descargado, se basa en la clasificación de 120 diferentes razas de perros. El objetivo del proyecto es crear un clasificador capaz de determinar la raza de un perro a partir de una foto, el dataset se encuentra en https://www.kaggle.com/c/dog-breed-identification/data y la lista de razas es la siguiente:
# ![image.png](data:image/png;base64,...)

# %%
# IMPORTANTE ANTES DE DESCARGAR UN DATASET !!!
# Antes de descargar el dataset debemos ir a https://www.kaggle.com/c/$nameCompetition/data y aceptar las "Competition Rules"
# En caso de no realizar el paso anterior al descargar el dataset obtenedremos el siguiente mensaje "403 - Forbidden"
# AHORA SI: Descarguemos un dataset de cierta competición
# !kaggle competitions download -c dog-breed-identification
#NOTA: El nombre del dataset de competición a descargar se informará en el documento en el que se presenten las parejas formadas
# Out:
# ...
#  99% 684M/691M [00:03<00:00, 214MB/s]
# 100% 691M/691M [00:03<00:00, 238MB/s]

# %%
# Creemos un directorio para descomprimir los datos
# !mkdir my_dataset

# %%
# Descomprimimos los datos y los dejamos listos para trabajar
# %%capture
# !unzip dog-breed-identification.zip -d my_dataset

# %% [markdown]
# ## **4. Inspección del conjunto de datos**
# #### Vamos a conocer cómo es el conjunto de datos antes de empezar a crear el modelo clasificador.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/my_dataset/labels.csv')
#observamos el tamaño de los datos
print(df.shape)
print(df.head())
# Out:
# (10222, 2)
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
# Visualizamos una imagen del dataset
# Se puede concluir que las imágenes tienen diferente tamaño
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('/content/my_dataset/train/' + str(df.loc[7000][0]) + '.jpg')
plt.imshow(img)
print(img.size)
# Out:
# 252000

# %% [markdown]
# ## **5. Acondicionamiento del conjunto de datos**
# ####Todas las imágenes del dataset tienen diferentes dimensiones, así que se realizará un procedimiento de redimencionamiento de imagen, y para todo el dataset se trabajará con imágenes de 100x100 pixeles.

# %%
my_dataX = []
my_dataY = []
for i in range(len(df)):
  print("\r",round(i/len(df)*100,2),"%", end="")
  img = cv2.imread('/content/my_dataset/train/' + str(df.loc[i][0]) + '.jpg',
                   cv2.COLOR_BGR2RGB)
  img = cv2.resize(img,(100,100),interpolation = cv2.INTER_AREA)
  my_dataY.append(df.loc[i][1])
  my_dataX.append(img)
# Out:
#  99.99 %

# %%
# Visualizamos una imagen redimencionada 100x100 pixeles
plt.imshow(my_dataX[7000])

# %%
# Comprobamos la dimensión de los datos
my_dataX = np.array(my_dataX)
my_dataY = np.array(my_dataY)
print(my_dataX.shape)
print(my_dataY.shape)
my_dataY[7000]
# Out:
# (10222, 100, 100, 3)
# (10222,)
# 'wire-haired_fox_terrier'

# %%
# Muestra de las imágenes redimencionadas
import matplotlib.pyplot as plt
from PIL import Image
fig = plt.figure(figsize=(14,10))
for n in range(1, 29):
  fig.add_subplot(4, 7, n)
  img = my_dataX[n]
  plt.imshow(img)
  plt.title(my_dataY[n])
  plt.axis('off')

# %% [markdown]
# ## **6. Guardar / Cargar / Preparación Datos**
# ####Guardaremos los datos en el drive para optimizar la carga de datos y también generamos el programa de carga para futuras ejecuciones.

# %%
from google.colab import drive
drive.mount('/content/drive/')
BASE_FOLDER = '/content/drive/MyDrive/07MIAR_Proyecto_Programacion/'
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ##6.1 Guardar

# %%
#Guardamos los datos en google drive ya que el proceso de carga es costoso
# np.save(BASE_FOLDER + "my_dataX", my_dataX)
# np.save(BASE_FOLDER + "my_dataY", my_dataY)

# %% [markdown]
# ##6.2  Cargar

# %%
import numpy as np
#Cargamos los datos: my_dataX y my_dataY
my_dataX = np.load(BASE_FOLDER + "my_dataX.npy")
my_dataY = np.load(BASE_FOLDER + "my_dataY.npy")

# %% [markdown]
# ##6.3 Preparación datos

# %%
from tensorflow.keras.backend import expand_dims
#Normalizamos los datos 0-1 / cambio de nombre
dataX = my_dataX.astype("float") / 255.0
dataY = expand_dims(my_dataY, axis=1)
print(dataX.shape)
print(dataY.shape)
# Out:
# (10222, 100, 100, 3)
# (10222, 1)

# %%
# dividimos el train y el test con relación 80% y 20%
trainX, valX, testX = np.split(dataX, [int(len(dataX)*0.64), int(len(dataX)*0.8)])
trainY, valY, testY = np.split(dataY, [int(len(dataY)*0.64), int(len(dataY)*0.8)])
print(trainX.shape)
print(testX.shape)
print(valX.shape)
# Out:
# (6542, 100, 100, 3)
# (2045, 100, 100, 3)
# (1635, 100, 100, 3)

# %%
# Dimensiones del train y test
print('Train X: ', trainX.shape)
print('Train Y: ', trainY.shape)
print('Test X: ', testX.shape)
print('Test Y: ', testY.shape)
print('Val X: ', valX.shape)
print('Val Y: ', valY.shape)
# Out:
# Train X:  (6542, 100, 100, 3)
# Train Y:  (6542, 1)
# Test X:  (2045, 100, 100, 3)
# Test Y:  (2045, 1)
# Val X:  (1635, 100, 100, 3)
# Val Y:  (1635, 1)

# %% [markdown]
# ## **7. Estrategia 1: Entrenar desde cero o from scratch**
# La primera estrategia a comparar será una red neuronal profunda que el alumno debe diseñar, entrenar y optimizar. Se debe justificar empíricamente las decisiones que llevaron a la selección de la arquitectura e hiperparámetros final. Se espera que el alumno utilice todas las técnicas de regularización mostradas en clase de forma justificada para la mejora del rendimiento de la red neuronal (weight regularization, dropout, batch normalization, data augmentation, etc.).

# %% [markdown]
# ### 7.1 One hot encoding

# %%
# One hot - encoding de trainY y testY
# Se realiza un arreglo para las etiquetas de los 120 razas diferentes de perros
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
# trainY = to_categorical(trainY, num_classes=120)
uno = np.unique(trainY)
dos = np.unique(testY)
tres = np.unique(valY)
print(dos.shape)
datoY=trainY.copy()
tdatoY=testY.copy()
tvalY=valY.copy()
np.array(datoY)
cnt=0
for i in uno:
    for j in range(len(trainY)):
      if trainY[j]==i:
        datoY[j]=cnt
    cnt+=1
cnt=0
for i in dos:
    for j in range(len(testY)):
      if testY[j]==i:
        tdatoY[j]=cnt
    cnt+=1
cnt=0
for i in tres:
    for j in range(len(valY)):
      if valY[j]==i:
        tvalY[j]=cnt
    cnt+=1
print(tdatoY.shape)
print(testX.shape)
print(valX.shape)
trainY = to_categorical(datoY, num_classes=120)
testY = to_categorical(tdatoY, num_classes=120)
valY = to_categorical(tvalY, num_classes=120)
# Out:
# (120,)
# (2045, 1)
# (2045, 100, 100, 3)
# (1635, 100, 100, 3)

# %% [markdown]
# 7.2 Test: 3 Capas 32, 64 , 128 ReLu + Maxpool + Dropout. 1 Capa 512 ReLu

# %%
# Import the necessary packages
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Conv2D, Activation, Flatten, Dense, Dropout, BatchNormalization, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from google.colab import drive

#########################################
###### Definimos la arquitectura ########
#########################################
#BASE MODEL
# Definimos entradas
inputs = Input(shape=(trainX.shape[1], trainX.shape[2], trainX.shape[3]))

# Primer set de capas CONV => RELU => CONV => RELU => POOL
x1 = Conv2D(32, (3, 3), padding="same", activation="relu")(inputs) 
x1 = BatchNormalization()(x1) 
x1 = Conv2D(32, (3, 3), padding="same", activation="relu")(x1) 
x1 = BatchNormalization()(x1) 
x1 = MaxPooling2D(pool_size=(2, 2))(x1) 
x1 = Dropout(0.25)(x1) 

# Segundo set de capas CONV => RELU => CONV => RELU => POOL
x2 = Conv2D(64, (3, 3), padding="same", activation="relu")(x1) #(X)
x2 = BatchNormalization()(x2) #(X)
x2 = Conv2D(64, (3, 3), padding="same", activation="relu")(x2) #(X)
x2 = BatchNormalization()(x2) #(X)
x2 = MaxPooling2D(pool_size=(2, 2))(x2) #(X)
x2 = Dropout(0.25)(x2) #(X)

# Tercer set de capas CONV => RELU => CONV => RELU => POOL
x3 = Conv2D(256, (3, 3), padding="same", activation="relu")(x2) #(X)
x3 = BatchNormalization()(x3) #(X)
x3 = Conv2D(256, (3, 3), padding="same", activation="relu")(x3) #(X)
x3 = BatchNormalization()(x3) #(X)
x3 = MaxPooling2D(pool_size=(2, 2))(x3) #(X)
x3 = Dropout(0.25)(x3) #(X)

# TOP MODEL
# Primer (y único) set de capas FC => RELU
xfc = Flatten()(x3) #(X)
xfc = Dense(512, activation="relu")(xfc) #(X)
xfc = BatchNormalization()(xfc) #(X)
xfc = Dropout(0.5)(xfc) #(X)
# Clasificador softmax con 120 categorías
predictions = Dense(120, activation="softmax")(xfc) #(X)

# Unimos las entradas y el modelo mediante la función Model con parámetros inputs y ouputs (Consultar la documentación)
model_cnn = Model(inputs=inputs, outputs=predictions) #(X)

# Compilar el modelo
print("[INFO]: Compilando el modelo...")
model_cnn.compile(loss="categorical_crossentropy", optimizer=Adam(lr=0.001,decay=0, beta_1=0.9, beta_2=0.999, epsilon=1e-08), metrics=["accuracy"]) #(X)

# Entrenamiento de la red
print("[INFO]: Entrenando la red...")
H1 = model_cnn.fit(trainX, trainY, validation_split=0.2, batch_size=128, epochs=20, verbose=1) #(X)
# Out:
# [INFO]: Compilando el modelo...
# [INFO]: Entrenando la red...
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/20
# 41/41 [==============================] - 10s 153ms/step - loss: 5.2664 - accuracy: 0.0208 - val_loss: 5.8999 - val_accuracy: 0.0076
# Epoch 2/20
# 41/41 [==============================] - 4s 105ms/step - loss: 4.6272 - accuracy: 0.0508 - val_loss: 5.5036 - val_accuracy: 0.0107
# Epoch 3/20
# 41/41 [==============================] - 4s 105ms/step - loss: 4.1352 - accuracy: 0.1001 - val_loss: 9.9564 - val_accuracy: 0.0046
# Epoch 4/20
# 41/41 [==============================] - 4s 105ms/step - loss: 3.6376 - accuracy: 0.1666 - val_loss: 5.6710 - val_accuracy: 0.0122
# Epoch 5/20
# 41/41 [==============================] - 4s 105ms/step - loss: 2.8448 - accuracy: 0.3247 - val_loss: 6.7898 - val_accuracy: 0.0130
# ...

# %%
# Evaluación del modelo
print("[INFO]: Evaluando el modelo...")
# Efectuamos la predicción (empleamos el mismo valor de batch_size que en training)
predictions = model_cnn.predict(testX, batch_size=128) #(X)
# Sacamos el report para test
print(predictions.shape)
print(testX.shape)
testYY=np.argmax(testY,axis=1)
print(classification_report(testYY, predictions.argmax(axis=1)))
# Gráficas
x=20
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, x), H1.history["loss"], label="train_loss")
plt.plot(np.arange(0, x), H1.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, x), H1.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, x), H1.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# [INFO]: Evaluando el modelo...
# (2045, 120)
# (2045, 100, 100, 3)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        18
#            1       0.06      0.09      0.07        22
#            2       0.13      0.10      0.11        21
#            3       0.00      0.00      0.00        20
#            4       0.00      0.00      0.00        20
#            5       0.00      0.00      0.00        13
#            6       0.07      0.06      0.07        16
#            7       0.00      0.00      0.00        28
#            8       0.00      0.00      0.00        19
#            9       0.00      0.00      0.00        24
#           10       0.15      0.31      0.20        16
#           11       0.14      0.12      0.13        26
#           12       0.17      0.06      0.09        16
#           13       0.11      0.14      0.12        21
#           14       0.05      0.07      0.06        14
# ...

# %% [markdown]
# ### 7.3 Data Augmentation:

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15, # grados de rotacion aleatoria
    width_shift_range=0.2, # fraccion del total (1) para mover la imagen
    height_shift_range=0.2, # fraccion del total (1) para mover la imagen
    horizontal_flip=True, # girar las imagenes horizontalmente (eje vertical)
    # shear_range=0, # deslizamiento
    zoom_range=0.2, # rango de zoom
    # fill_mode='nearest', # como rellenar posibles nuevos pixeles
    # channel_shift_range=0.2 # cambios aleatorios en los canales de la imagen
)

# %% [markdown]
# ##7.4 Capas 5 32, 64, 128, 256, 512 ReLu + Maxpool + Dropout. 1 Capas  512 ReL

# %%
# Import the necessary packages
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Conv2D, Activation, Flatten, Dense,Dropout, BatchNormalization, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD, Adam
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from google.colab import drive
#########################################
###### Definimos la arquitectura ########
#########################################
# Definimos entradas
inputs = Input(shape=(trainX.shape[1], trainX.shape[2], trainX.shape[3]))
# Primer set de capas
x1 = Conv2D(32, (3, 3), padding="same", activation="relu")(inputs)
x1 = BatchNormalization()(x1)
x1 = MaxPooling2D(pool_size=(2, 2))(x1)
x1 = Dropout(0.25)(x1)
# Segundo set de capas
x2 = Conv2D(64, (3, 3), padding="same", activation="relu")(x1)
x2 = BatchNormalization()(x2)
x2 = MaxPooling2D(pool_size=(2, 2))(x2)
x2 = Dropout(0.25)(x2)
# Tercer set de capas
x3 = Conv2D(128, (3, 3), padding="same", activation="relu")(x2)
x3 = BatchNormalization()(x3)
x3 = MaxPooling2D(pool_size=(2, 2))(x3)
x3 = Dropout(0.25)(x3)
# Cuarto set de capas
x4 = Conv2D(256, (3, 3), padding="same", activation="relu")(x3)
x4 = BatchNormalization()(x4)
x4 = MaxPooling2D(pool_size=(2, 2))(x4)
x4 = Dropout(0.25)(x4)
# Quinto set de capas
x5 = Conv2D(512, (3, 3), padding="same", activation="relu")(x4)
x5 = BatchNormalization()(x5)
x5 = MaxPooling2D(pool_size=(2, 2))(x5)
x5 = Dropout(0.5)(x5)
# TOP MODEL
xfc = Flatten()(x5)
xfc = Dense(512, activation="relu")(xfc)
xfc = BatchNormalization()(xfc)
xfc = Dropout(0.5)(xfc)
# Clasificador softmax 2 categorías
predictions = Dense(120, activation="softmax")(xfc)
# Unimos las entradas y el modelo mediante la función Model con parámetros␣inputs y ouputs
model_aug15 = Model(inputs=inputs, outputs=predictions)
# Compilar el modelo
print("[INFO]: Compilando el modelo...")
model_aug15.compile(loss="categorical_crossentropy", optimizer=Adam(lr=0.001,decay=0, beta_1=0.9, beta_2=0.999, epsilon=1e-08),
metrics=["accuracy"])
# Entrenamiento de la red
print("[INFO]: Entrenando la red...")
epocas = 30
bs = 256
#entrenar con menos para que vaya más rápido
H2 = model_aug15.fit(datagen.flow(trainX, trainY, batch_size=bs),steps_per_epoch = len(trainX)*2/bs,epochs=epocas,  validation_data=(valX, valY), workers = 2)
# Almacenamos el modelo empleando la función mdoel.save de Keras
model_aug15.save(BASE_FOLDER+"model_aug15.h5")
# Out:
# [INFO]: Compilando el modelo...
# [INFO]: Entrenando la red...
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/30
# 51/51 [==============================] - 20s 348ms/step - loss: 5.6711 - accuracy: 0.0151 - val_loss: 6.2156 - val_accuracy: 0.0055
# Epoch 2/30
# 51/51 [==============================] - 21s 397ms/step - loss: 5.1586 - accuracy: 0.0260 - val_loss: 7.3952 - val_accuracy: 0.0086
# Epoch 3/30
# 51/51 [==============================] - 18s 347ms/step - loss: 4.9047 - accuracy: 0.0339 - val_loss: 7.7777 - val_accuracy: 0.0055
# Epoch 4/30
# 51/51 [==============================] - 18s 340ms/step - loss: 4.7334 - accuracy: 0.0408 - val_loss: 8.6794 - val_accuracy: 0.0061
# Epoch 5/30
# 51/51 [==============================] - 18s 342ms/step - loss: 4.5835 - accuracy: 0.0477 - val_loss: 8.5602 - val_accuracy: 0.0073
# ...

# %%
import matplotlib.pyplot as plt
# Evaluación del modelo
print("[INFO]: Evaluando el modelo...")
# Efectuamos la predicción (empleamos el mismo valor de batch_size que en␣training)
predictions = model_aug15.predict(testX, batch_size=bs)
# Sacamos el report para test
testYY=np.argmax(testY,axis=1)
#print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1),␣target_names=labelNames))
# print(classification_report(testYY, predictions.argmax(axis=1))) #(X)
# Gráficas
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, epocas), H2.history["loss"], label="train_loss")
plt.plot(np.arange(0, epocas), H2.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, epocas), H2.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, epocas), H2.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
model_aug15.summary()
# Out:
# [INFO]: Evaluando el modelo...
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  conv2d_100 (Conv2D)         (None, 100, 100, 32)      896
#
#  batch_normalization_101 (Ba  (None, 100, 100, 32)     128
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 50, 50, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 50, 50, 32)        0
#
#  conv2d_101 (Conv2D)         (None, 50, 50, 64)        18496
#
#  batch_normalization_102 (Ba  (None, 50, 50, 64)       256
#  tchNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 25, 25, 64)        0
#
#  conv2d_102 (Conv2D)         (None, 25, 25, 128)       73856
#
#  batch_normalization_103 (Ba  (None, 25, 25, 128)      512
#  tchNormalization)
#
# ...

# %% [markdown]
# ##**8. Estrategia 2: Red pre-entrenada**
# La segunda estrategia a comparar debe incluir la utilización de una red preentrenada con el dataset
# ImageNet, llevando a cabo tareas de transfer learning y fine-tuning para resolver la tarea de clasificación asignada. Deben compararse al menos dos tipos de arquitecturas (VGGs, ResNet50,
# Xception, InceptionV3, InceptionResNetV2, MobileNetV2, DenseNet, ResNet) y se debe seleccionar la que mayor precisión proporcione (información sobre las arquitecturas disponibles en
# https://keras.io/applications/). Se espera que el/la alumnx utilice todas las técnicas de regularización mostradas en clase de forma justificada para la mejora del rendimie

# %% [markdown]
# ##8.1 VGG16

# %%
#Imports
# %matplotlib inline
import matplotlib.pyplot as plt
import PIL
import tensorflow as tf
import numpy as np
import os
#Para Keras API
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.applications import VGG16,ResNet50
from tensorflow.keras.applications.vgg16 import preprocess_input,decode_predictions
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.applications import imagenet_utils
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
# my_dataX = imagenet_utils.preprocess_input(my_dataX/255)
# Partición en train, val y test
trainX, valX, testX = np.split(my_dataX, [int(len(my_dataX)*0.64),int(len(my_dataX)*0.8)])
trainY, valY, testY = np.split(my_dataY, [int(len(my_dataY)*0.64),int(len(my_dataY)*0.8)])
# Dimensiones del train, val y test
print(trainX.shape)
print(trainY.shape)
print(valX.shape)
print(valY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (6542, 100, 100, 3)
# (6542,)
# (1635, 100, 100, 3)
# (1635,)
# (2045, 100, 100, 3)
# (2045,)

# %%
 #Modelado de la red
base_model = VGG16(weights='imagenet',
include_top=False, #Al nor ser el tamaño 224x224x3, hay que␣definir el top model
input_shape=(100,100,3)) #32x32x3 Es el tamño se nuestras␣imágenes
#Top model
base_model.trainable = True #TRANSFER LEARNING
VGG16_model = Sequential()
VGG16_model.add(base_model)
VGG16_model.add(layers.Flatten())
VGG16_model.add(layers.Dropout(0.50))
VGG16_model.add(layers.Dense(256, activation='relu'))
VGG16_model.add(layers.Dense(120, activation='softmax'))
VGG16_model.summary()
# Out:
# ...
# 58900480/58889256 [==============================] - 0s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  flatten_3 (Flatten)         (None, 4608)              0
#
#  dropout_11 (Dropout)        (None, 4608)              0
#
#  dense_7 (Dense)             (None, 256)               1179904
#
#  dense_8 (Dense)             (None, 120)               30840
#
# ...
# Total params: 15,925,432
# Trainable params: 15,925,432
# Non-trainable params: 0
# _________________________________________________________________

# %%
# One hot - encoding de trainY y testY
# Se realiza un arreglo para las etiquetas de los 120 razas diferentes de perros
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
# trainY = to_categorical(trainY, num_classes=120)
uno = np.unique(trainY)
dos = np.unique(testY)
tres = np.unique(valY)
print(dos.shape)
datoY=trainY.copy()
tdatoY=testY.copy()
tvalY=valY.copy()
np.array(datoY)
cnt=0
for i in uno:
    for j in range(len(trainY)):
      if trainY[j]==i:
        datoY[j]=cnt
    cnt+=1
cnt=0
for i in dos:
    for j in range(len(testY)):
      if testY[j]==i:
        tdatoY[j]=cnt
    cnt+=1
cnt=0
for i in tres:
    for j in range(len(valY)):
      if valY[j]==i:
        tvalY[j]=cnt
    cnt+=1
print(tdatoY.shape)
print(testX.shape)
print(valX.shape)
trainY = to_categorical(datoY, num_classes=120)
testY = to_categorical(tdatoY, num_classes=120)
valY = to_categorical(tvalY, num_classes=120)
# Out:
# (120,)
# (2045,)
# (2045, 100, 100, 3)
# (1635, 100, 100, 3)

# %%
#Compilación de la Red
print("[INFO]: Compilando el modelo...")
VGG16_model.compile(loss="categorical_crossentropy", optimizer=Adam(lr=0.001,decay=0, beta_1=0.9, beta_2=0.999, epsilon=1e-08), metrics=["accuracy"])
bs = 64
epoca = 30
# Entrenamiento de la red, con una data de validacion del 23.8%
print("[INFO]: Entrenando la red...")
H3 = VGG16_model.fit(trainX, trainY, validation_data=(valX, valY),batch_size=bs, epochs=epoca, verbose=1)
# Out:
# [INFO]: Compilando el modelo...
# [INFO]: Entrenando la red...
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 103/103 [==============================] - 13s 112ms/step - loss: 4.7733 - accuracy: 0.0130 - val_loss: 4.7902 - val_accuracy: 0.0104
# Epoch 2/30
# 103/103 [==============================] - 11s 109ms/step - loss: 4.7727 - accuracy: 0.0130 - val_loss: 4.7901 - val_accuracy: 0.0104
# Epoch 3/30
# 103/103 [==============================] - 11s 109ms/step - loss: 4.7727 - accuracy: 0.0130 - val_loss: 4.7905 - val_accuracy: 0.0104
# Epoch 4/30
# 103/103 [==============================] - 11s 109ms/step - loss: 4.7725 - accuracy: 0.0130 - val_loss: 4.7906 - val_accuracy: 0.0104
# Epoch 5/30
# ...

# %%
# Evaluación del modelo
print("[INFO]: Evaluando el modelo...")
# Efectuamos la predicción (empleamos el mismo valor de batch_size que en␣training)
predictions = VGG16_model.predict(testX, batch_size=bs)
# Sacamos el report para test
testYY=np.argmax(testY,axis=1)
# print(classification_report(testYY, predictions.argmax(axis=1)))
# Gráficas
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, epoca), H3.history["loss"], label="train_loss")
plt.plot(np.arange(0, epoca), H3.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, epoca), H3.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, epoca), H3.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy VGG16")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# [INFO]: Evaluando el modelo...

# %% [markdown]
# ##Con este método para las diferentes clases no existe variación así que se tomará otra metodología con DataAugmentation  y callbacks

# %% [markdown]
# ##8.2 Transfer Learning: VGG16 con DataAumengtation

# %%
# !mkdir 'my_dataset/train data'

# %%
import pandas as pd
import numpy as np
import os
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator

df = pd.read_csv('my_dataset/labels.csv',sep=',')
df['id'] = [i + '.jpg' for i in df['id']]
print(df.shape)
def preprocess(p):
  i = cv2.imread(p)
  i = cv2.cvtColor(i, cv2.COLOR_BGR2RGB)
  i = cv2.resize(i, (150,150))
  return i
# !mkdir 'my_dataset/train data'
l = os.listdir('my_dataset/train')
for i in range(len(l)):
  path = 'my_dataset/train/' + l[i]
  image = preprocess(path)
  cv2.imwrite('my_dataset/train data/' + l[i],image)
# Out:
# (10222, 2)

# %%
idg = ImageDataGenerator(rescale = 1/255.0, rotation_range=90,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         shear_range=0.2,
                         zoom_range=0.25,
                         horizontal_flip=True,
                         fill_mode='nearest',validation_split=0.1)
bs=64
from matplotlib import test
imagen=[]
files=[]
for i in range(len(df)):
  file = df.id[i]
  img = cv2.imread('my_dataset/train/' + file+'.jpg')
  imagen.append(img)
  files.append(file)

imagen=np.array(imagen)

# %%
train_gen = idg.flow_from_dataframe(dataframe=df, directory='my_dataset/train data',x_col='id',y_col='breed',
                                    target_size=(150,150),
                                    batch_size = 64, subset='training')
val_gen = idg.flow_from_dataframe(dataframe=df, directory='my_dataset/train data',x_col='id',y_col='breed',
                                    target_size=(150,150),
                                    batch_size = 64, subset='validation')
from tensorflow.keras import applications
transfer_model = applications.VGG16(include_top=False,
                                          weights='imagenet',
                                          input_shape=(150,150,3))
# Out:
# Found 9200 validated image filenames belonging to 120 classes.
# Found 1022 validated image filenames belonging to 120 classes.

# %%
import tensorflow as tf
for layer in transfer_model.layers:
  layer.trainable = False
model = tf.keras.models.Sequential()
model.add(transfer_model)
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(1024,activation='relu'))
model.add(tf.keras.layers.Dense(512,activation='relu'))
model.add(tf.keras.layers.Dense(120,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  max_pooling2d_13 (MaxPoolin  (None, 2, 2, 512)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dropout_12 (Dropout)        (None, 2048)              0
#
#  dense_9 (Dense)             (None, 1024)              2098176
#
#  dense_10 (Dense)            (None, 512)               524800
#
#  dense_11 (Dense)            (None, 120)               61560
#
# ...
# Total params: 17,399,224
# Trainable params: 2,684,536
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
bs=64
callback = [tf.keras.callbacks.EarlyStopping(monitor='val_acc',patience=3)]
model.compile(optimizer='SGD', loss=tf.keras.losses.categorical_crossentropy, metrics='accuracy')
H4 = model.fit(train_gen, batch_size=bs, epochs=10, validation_data=val_gen, callbacks=[callback])
# Out:
# Epoch 1/10
# ...
# 144/144 [==============================] - 60s 410ms/step - loss: 4.8100 - accuracy: 0.0121 - val_loss: 4.7649 - val_accuracy: 0.0166
# Epoch 2/10
# ...
# 144/144 [==============================] - 57s 398ms/step - loss: 4.7785 - accuracy: 0.0160 - val_loss: 4.7481 - val_accuracy: 0.0245
# Epoch 3/10
# ...
# 144/144 [==============================] - 57s 398ms/step - loss: 4.7554 - accuracy: 0.0185 - val_loss: 4.7274 - val_accuracy: 0.0166
# Epoch 4/10
# ...
# 144/144 [==============================] - 58s 400ms/step - loss: 4.7388 - accuracy: 0.0205 - val_loss: 4.7049 - val_accuracy: 0.0215
# Epoch 5/10
# ...
# 144/144 [==============================] - 58s 401ms/step - loss: 4.7158 - accuracy: 0.0242 - val_loss: 4.6755 - val_accuracy: 0.0391
# Epoch 6/10
# ...
# 144/144 [==============================] - 58s 402ms/step - loss: 4.6977 - accuracy: 0.0274 - val_loss: 4.6530 - val_accuracy: 0.0391
# Epoch 7/10
# ...

# %%
plt.style.use('ggplot')
plt.figure()
x=10
plt.plot(np.arange(0,x), H4.history['loss'], label='train_loss')
plt.plot(np.arange(0,x), H4.history['val_loss'], label='val_loss')
plt.plot(np.arange(0,x), H4.history['accuracy'], label='train_acc')
plt.plot(np.arange(0,x), H4.history['val_accuracy'], label='val_acc')
plt.title('Training Loss an Accuracy')
plt.xlabel('Epoch #')
plt.ylabel('Loss/Accuracy')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Con el resultado obtenido se mejora bastante y se observa como la función de pérdida decae conforme avanza el entrenamiento

# %% [markdown]
# ##8.3 Transfer Learning: INCEPTION V3 con DataAumengtation

# %%
import pandas as pd
import numpy as np
import os
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator

df = pd.read_csv('my_dataset/labels.csv',sep=',')
df['id'] = [i + '.jpg' for i in df['id']]
print(df.shape)
def preprocess(p):
  i = cv2.imread(p)
  i = cv2.cvtColor(i, cv2.COLOR_BGR2RGB)
  i = cv2.resize(i, (150,150))
  return i
# !mkdir 'my_dataset/train data'
l = os.listdir('my_dataset/train')
for i in range(len(l)):
  path = 'my_dataset/train/' + l[i]
  image = preprocess(path)
  cv2.imwrite('my_dataset/train data/' + l[i],image)
# Out:
# (10222, 2)

# %%
idg = ImageDataGenerator(rescale = 1/255.0, rotation_range=90,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         shear_range=0.2,
                         zoom_range=0.25,
                         horizontal_flip=True,
                         fill_mode='nearest',validation_split=0.1)
bs=64
from matplotlib import test
imagen=[]
files=[]
for i in range(len(df)):
  file = df.id[i]
  img = cv2.imread('my_dataset/train/' + file+'.jpg')
  imagen.append(img)
  files.append(file)

imagen=np.array(imagen)

# %%
train_gen = idg.flow_from_dataframe(dataframe=df, directory='my_dataset/train data',x_col='id',y_col='breed',
                                    target_size=(150,150),
                                    batch_size = 64, subset='training')
val_gen = idg.flow_from_dataframe(dataframe=df, directory='my_dataset/train data',x_col='id',y_col='breed',
                                    target_size=(150,150),
                                    batch_size = 64, subset='validation')
from tensorflow.keras import applications
transfer_model = applications.InceptionV3(include_top=False,
                                          weights='imagenet',
                                          input_shape=(150,150,3))
# Out:
# Found 9200 validated image filenames belonging to 120 classes.
# Found 1022 validated image filenames belonging to 120 classes.
# ...
# 87924736/87910968 [==============================] - 1s 0us/step

# %%
import tensorflow as tf
for layer in transfer_model.layers:
  layer.trainable = False
model = tf.keras.models.Sequential()
model.add(transfer_model)
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(1024,activation='relu'))
model.add(tf.keras.layers.Dense(512,activation='relu'))
model.add(tf.keras.layers.Dense(120,activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  inception_v3 (Functional)   (None, 3, 3, 2048)        21802784
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 2048)       0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 120)               61560
#
# ...
# Total params: 24,487,320
# Trainable params: 2,684,536
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
callback = [tf.keras.callbacks.EarlyStopping(monitor='val_acc',patience=3)]
model.compile(optimizer='SGD', loss=tf.keras.losses.categorical_crossentropy, metrics='accuracy')
H5 = model.fit(train_gen, batch_size=bs, epochs=10, validation_data=val_gen, callbacks=[callback])
# Out:
# Epoch 1/10
# ...
# 144/144 [==============================] - 65s 416ms/step - loss: 3.4228 - accuracy: 0.2036 - val_loss: 3.3925 - val_accuracy: 0.1928
# Epoch 2/10
# ...
# 144/144 [==============================] - 57s 396ms/step - loss: 3.4117 - accuracy: 0.2014 - val_loss: 3.2890 - val_accuracy: 0.2270
# Epoch 3/10
# ...
# 144/144 [==============================] - 58s 400ms/step - loss: 3.3693 - accuracy: 0.2137 - val_loss: 3.2604 - val_accuracy: 0.2016
# Epoch 4/10
# ...
# 144/144 [==============================] - 57s 398ms/step - loss: 3.3522 - accuracy: 0.2142 - val_loss: 3.3240 - val_accuracy: 0.2172
# Epoch 5/10
# ...
# 144/144 [==============================] - 57s 397ms/step - loss: 3.3556 - accuracy: 0.2198 - val_loss: 3.2315 - val_accuracy: 0.2211
# Epoch 6/10
# ...
# 144/144 [==============================] - 57s 397ms/step - loss: 3.3037 - accuracy: 0.2226 - val_loss: 3.2697 - val_accuracy: 0.2231
# Epoch 7/10
# ...

# %%
plt.style.use('ggplot')
plt.figure()
x=10
plt.plot(np.arange(0,x), H5.history['loss'], label='train_loss')
plt.plot(np.arange(0,x), H5.history['val_loss'], label='val_loss')
plt.plot(np.arange(0,x), H5.history['accuracy'], label='train_acc')
plt.plot(np.arange(0,x), H5.history['val_accuracy'], label='val_acc')
plt.title('Training Loss an Accuracy')
plt.xlabel('Epoch #')
plt.ylabel('Loss/Accuracy')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##8.4 Fine Tuning

# %%
#Modelado de la red
# Congelamos las capas de los 3 primeros bloques convolucionales, y el cuarto y quinto se re-entrenan
# En base_model.layers.name tenemos la información del nombre de la capa
for layer in model.layers:
  if layer.name == 'block4_conv1':
    break
layer.trainable = False
print('Capa ' + layer.name + ' congelada...')
# Cogemos la última capa del model y le añadimos nuestro clasificador(top_model)
last = base_model.layers[-1].output
x = Flatten()(last)
x = Dense(256, activation='relu', name='fc1')(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu', name='fc2')(x)
x = Dense(120, activation='softmax', name='predictions')(x)
model_n = Model(base_model.input, x)
# Out:
# Capa dense_11 congelada...

# %%
callback = [tf.keras.callbacks.EarlyStopping(monitor='val_acc',patience=3)]
model.compile(optimizer='SGD', loss=tf.keras.losses.categorical_crossentropy, metrics='accuracy')
H6 = model.fit(train_gen, batch_size=bs, epochs=10, validation_data=val_gen, callbacks=[callback])
# Out:
# Epoch 1/10
# ...
# 144/144 [==============================] - 60s 412ms/step - loss: 4.4836 - accuracy: 0.0475 - val_loss: 4.3985 - val_accuracy: 0.0558
# Epoch 2/10
# ...
# 144/144 [==============================] - 59s 411ms/step - loss: 4.4516 - accuracy: 0.0475 - val_loss: 4.3851 - val_accuracy: 0.0626
# Epoch 3/10
# ...
# 144/144 [==============================] - 58s 403ms/step - loss: 4.4031 - accuracy: 0.0538 - val_loss: 4.3651 - val_accuracy: 0.0587
# Epoch 4/10
# ...
# 144/144 [==============================] - 58s 405ms/step - loss: 4.3812 - accuracy: 0.0522 - val_loss: 4.3425 - val_accuracy: 0.0577
# Epoch 5/10
# ...
# 144/144 [==============================] - 58s 403ms/step - loss: 4.3661 - accuracy: 0.0595 - val_loss: 4.3081 - val_accuracy: 0.0685
# Epoch 6/10
# ...
# 144/144 [==============================] - 59s 406ms/step - loss: 4.3347 - accuracy: 0.0626 - val_loss: 4.2495 - val_accuracy: 0.0705
# Epoch 7/10
# ...

# %% [markdown]
# ##8.5 Gráficas

# %%
# Gráficas
fig, axs = plt.subplots(2, 3)
#VGG16
epoca=20
axs[0, 0].plot(np.arange(0, epoca), H1.history["loss"], label="train_loss")
axs[0, 0].plot(np.arange(0, epoca), H1.history["val_loss"],label="val_loss")
axs[0, 0].plot(np.arange(0, epoca), H1.history["accuracy"],label="train_acc")
axs[0, 0].plot(np.arange(0, epoca), H1.history["val_accuracy"],label="val_acc")
axs[0, 0].title.set_text("FSC 1")
axs[0, 0].legend()
epoca=30
axs[0, 1].plot(np.arange(0, epoca), H2.history["loss"],label="train_loss")
axs[0, 1].plot(np.arange(0, epoca), H2.history["val_loss"],label="val_loss")
axs[0, 1].plot(np.arange(0, epoca), H2.history["accuracy"],label="train_acc")
axs[0, 1].plot(np.arange(0, epoca), H2.history["val_accuracy"],label="val_acc")
axs[0, 1].title.set_text("FSC 2")
axs[0, 1].legend()
epoca=30
axs[0, 2].plot(np.arange(0, epoca), H3.history["loss"],label="train_loss")
axs[0, 2].plot(np.arange(0, epoca), H3.history["val_loss"],label="val_loss")
axs[0, 2].plot(np.arange(0, epoca), H3.history["accuracy"],label="train_acc")
axs[0, 2].plot(np.arange(0, epoca), H3.history["val_accuracy"],label="val_acc")
axs[0, 2].title.set_text("VGG16")
axs[0, 2].legend()
epoca=10
axs[1, 0].plot(np.arange(0, epoca), H4.history["loss"],label="train_loss")
axs[1, 0].plot(np.arange(0, epoca), H4.history["val_loss"],label="val_loss")
axs[1, 0].plot(np.arange(0, epoca), H4.history["accuracy"],label="train_acc")
axs[1, 0].plot(np.arange(0, epoca), H4.history["val_accuracy"],label="val_acc")
axs[1, 0].title.set_text("VGG16 TL")
axs[1, 0].legend()
epoca=10
axs[1, 1].plot(np.arange(0, epoca), H5.history["loss"],label="train_loss")
axs[1, 1].plot(np.arange(0, epoca), H5.history["val_loss"],label="val_loss")
axs[1, 1].plot(np.arange(0, epoca), H5.history["accuracy"],label="train_acc")
axs[1, 1].plot(np.arange(0, epoca), H5.history["val_accuracy"],label="val_acc")
axs[1, 1].title.set_text("INC.V3 TL")
axs[1, 1].legend()
epoca=10
axs[1, 2].plot(np.arange(0, epoca), H6.history["loss"],label="train_loss")
axs[1, 2].plot(np.arange(0, epoca), H6.history["val_loss"],label="val_loss")
axs[1, 2].plot(np.arange(0, epoca), H6.history["accuracy"],label="train_acc")
axs[1, 2].plot(np.arange(0, epoca), H6.history["val_accuracy"],label="val_acc")
axs[1, 2].title.set_text("INC.V3 FT")
axs[1, 2].legend()
plt.figure(figsize=(14,10))
plt.show()

# %% [markdown]
# ##8.6 RESUMEN RESULTADOS:

# %% [markdown]
# Como resultado se tiene que, en las primeros experimentos con la estrategia "from scratch" se tiene un overfitting pero mejora radicalmente con técnicas de *Dropout* en "from scratch 2", pero aun así es inestable y la precisión es muy baja.
#
# Cuando usamos transfer learning, usamos dos modelos pre entrenados. "VGG16" e "INCEPTION V3" para lo cual en un primer experimento no existe variación de parámetros, así que no se tomó en cuenta ese resultado y por consiguiente se modela con Dropout e imágenes de tamaño de 150x150 pixeles. Obteniendo un mejor resultado en VGG16 TL.
#
# Se probó el siguiente modelo con INCEPTION V3, y la precisión disminuye aunque la función de pérdida mejora con forme va entrenando y se probó el método de *FineTuning* y mejora bastante.
# Como resultado final se puede verificar que el BAse Model con VGG16 y aplicando transfer learning y aplicando dropout y dataaumengtation, fue el mejor método para el entrenamiento del set de datos.

# %% [markdown]
# ##**9. Generación de documento PDF a partir del Colab Notebook (fichero ”.ipynb”)**

# %%
# Ejecutando los siguientes comandos en la última celda del Colab Notebook se␣convierte de ".ipynb" a PDF
# En caso de querer ocultar la salida de una celda puesto que no tenga␣relevancia se debe insertar
# el comando %%capture al inicio de la misma. Véase la celda que contiene !ls␣test en este Notebook.

# %%
name_IPYNB_file ='Proyecto Final.ipynb'
get_ipython().system(
" apt install  texlive-generic-recommended >> /dev/null"
)
get_ipython().system(
    "jupyter nbconvert --output-dir='$BASE_FOLDER'␣'$BASE_FOLDER''$name_IPYNB_file' --to pdf"
)
